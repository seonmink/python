# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action="ignore") #경고 표시 제거는 일시적으로만 하자... 중요한 내용일수도

import matplotlib.font_manager as fm #한글 안깨지게
font_name=fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mpl # - 표시 정상적으로 되도록
mpl.rcParams["axes.unicode_minus"]=False

import urllib.request as req
from urllib.request import urlopen
from urllib.error import HTTPError, URLError
import urllib.parse
from bs4 import BeautifulSoup
import requests

# %%
word = '동작구'
url="https://www.mangoplate.com/search/"+word
#page=urlopen(url)
#page
#그냥 입력하면 403 forbidden error --> 권한 받기 위해 추가 작업 필요

headers={"User-Agent":"Mozilla/5.0"}
page=requests.get(url, headers=headers)
page

soup=BeautifulSoup(page.text, "html.parser") #request라는 모듈로 가져왔을 시에는 text 가져와야 함
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="telephone=no" name="format-detection">
# <meta content="동작구 맛집 인기 검색순위 | 맛집 추천, 망고플레이트" name="subject"/>
# <meta content="동작구의 맛집 검색결과는 1,243건 입니다. 동작구의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요." name="description"/>
# <meta content="주전부리, 스시로로, 리얼후라이, 김일성 쭈꾸미, 프랑세즈, 유정쌈밥, 키친 오브 블랙덕, 우뇽파스타, 서일순대국, 나귀와플라타너스" name="keywords"/>
# <meta content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/17491/reviews/22c85ec93e1f.jpg" name="image">
# <meta content="http://www.mangoplate.com/search/%EB%8F%99%EC%9E%91%EA%B5%AC" property="og:url">
# <meta content="website" property="og:type">
# <meta content="동작구 맛집 인기 검색순위 | 맛집 추천, 망고플레이트" property="og:title"/>
# <meta content="동작구의 맛집 검색결과는 1,243건 입니다. 동작구의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요." property="og:description"/>
# <meta content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/17491/reviews/22c85ec93e1f.jpg" property="og:image"/>
# <link href="https://www.mangoplate.com/search/%EB%8F%99%EC%9E%91%EA%B5%AC?page=2" rel="next"/>
# <!-- Twitter Meta -->
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="@MangoPlate" property="twitter:site"/>
# <meta content="http://www.mangoplate.com/search/%EB%8F%99%EC%9E%91%EA%B5%AC" property="twitter:url"/>
# <meta content="동작구 맛집 인기 검색순위 | 맛집 추천, 망고플레이트" property="twitter:title"/>
# <meta content="동작구의 맛집 검색결과는 1,243건 입니다. 동작구의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요." property="twitter:description"/>
# <meta content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/17491/reviews/22c85ec93e1f.jpg" property="twitter:image"/>
# <meta content="476661545693695" property="fb:app_id">
# <meta content="mangoplate://restaurants?search_keyword=동작구" property="al:ios:url">
# <meta content="628509224" property="al:ios:app_store_id">
# <meta content="MangoPlate" property="al:ios:app_name">
# <meta content="mangoplate://restaurants?search_keyword=동작구" property="al:android:url">
# <meta content="com.mangoplate" property="al:android:package">
# <meta content="MangoPlate" property="al:android:app_name"/>
# <title>동작구 맛집 인기 검색순위 | 맛집 추천, 망고플레이트</title>
# <link href="/assets/dist/search-6cda6f69c2f1816a036e65c466c5572c9b9a616def74933816847007b6d29bc7.css" media="screen" rel="stylesheet"/>
# <link href="/assets/favicon.ico" rel="shortcut icon"/>
# <!-- Representative URL Setting-->
# <link href="https://www.mangoplate.com/search/%EB%8F%99%EC%9E%91%EA%B5%AC" rel="canonical"/>
# <link href="https://www.mangoplate.com/search/%EB%8F%99%EC%9E%91%EA%B5%AC" hreflang="ko" rel="alternate"/>
# <link href="https://www.mangoplate.com/en/search/%EB%8F%99%EC%9E%91%EA%B5%AC" hreflang="en" rel="alternate"/>
# <link href="https://www.mangoplate.com/zh/search/%EB%8F%99%EC%9E%91%EA%B5%AC" hreflang="zh" rel="alternate"/>
# <link href="https://www.mangoplate.com/amp/search/%EB%8F%99%EC%9E%91%EA%B5%AC" rel="amphtml">
# <!-- Google Adsense Script -->
# <script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script type="application/ld+json">{"@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.mangoplate.com/restaurants/A2wHyagv8QkV"},{"@type":"ListItem","position":2,"url":"https://www.mangoplate.com/restaurants/H7qgftiPmv"},{"@type":"ListItem","position":3,"url":"https://www.mangoplate.com/restaurants/0D-yLUXut2C6"},{"@type":"ListItem","position":4,"url":"https://www.mangoplate.com/restaurants/8bMnQH_r40am"},{"@type":"ListItem","position":5,"url":"https://www.mangoplate.com/restaurants/drXX2BDsGZ"},{"@type":"ListItem","position":6,"url":"https://www.mangoplate.com/restaurants/RztxiJSWE4"},{"@type":"ListItem","position":7,"url":"https://www.mangoplate.com/restaurants/mseYsQL8gXuC"},{"@type":"ListItem","position":8,"url":"https://www.mangoplate.com/restaurants/prl1JPZOWqag"},{"@type":"ListItem","position":9,"url":"https://www.mangoplate.com/restaurants/hJd3wPlT-Hk_"},{"@type":"ListItem","position":10,"url":"https://www.mangoplate.com/restaurants/K1lhL2EtJRt8"},{"@type":"ListItem","position":11,"url":"https://www.mangoplate.com/restaurants/u_FH24C5Kc"},{"@type":"ListItem","position":12,"url":"https://www.mangoplate.com/restaurants/NlrcpMeHFOzg"},{"@type":"ListItem","position":13,"url":"https://www.mangoplate.com/restaurants/dFjEJPa93yJf"},{"@type":"ListItem","position":14,"url":"https://www.mangoplate.com/restaurants/yhLPJnTWt17m"},{"@type":"ListItem","position":15,"url":"https://www.mangoplate.com/restaurants/sBb2ypsWeE"},{"@type":"ListItem","position":16,"url":"https://www.mangoplate.com/restaurants/oWZ4cQgJ7FPV"},{"@type":"ListItem","position":17,"url":"https://www.mangoplate.com/restaurants/1OVrnWYkmikK"},{"@type":"ListItem","position":18,"url":"https://www.mangoplate.com/restaurants/hVLHSCT8aE"},{"@type":"ListItem","position":19,"url":"https://www.mangoplate.com/restaurants/lVwSxatR9MQq"},{"@type":"ListItem","position":20,"url":"https://www.mangoplate.com/restaurants/hxvT6OzhZLrb"}],"@context":"http://schema.org","@id":"https://www.mangoplate.com"}</script>
# <script id="dfp_ads" type="application/json">[{"id":21,"platform":"web_desktop","page":"init","inventory":"all","sizes":null,"tag":"/395211568/init/desktop_all","enabled":true,"created_at":"2017-06-23T01:58:50.000+09:00","updated_at":"2018-11-16T17:06:11.000+09:00","args":{"display_type":{"value":"popup"}}},{"id":43,"platform":"web_mobile","page":"init","inventory":"all","sizes":null,"tag":"/395211568/init/mobile_all","enabled":true,"created_at":"2020-02-12T01:57:59.000+09:00","updated_at":"2020-03-23T00:29:37.000+09:00","args":{"display_type":{"value":"popup"},"display":{"value":"once"}}},{"id":53,"platform":"web_mobile","page":"init","inventory":"popop_use_app","sizes":null,"tag":"","enabled":true,"created_at":"2020-01-30T01:49:26.000+09:00","updated_at":"2020-03-06T12:00:28.000+09:00","args":{}},{"id":57,"platform":"web_mobile","page":"init","inventory":"area_use_app","sizes":null,"tag":"","enabled":true,"created_at":"2020-01-30T01:49:26.000+09:00","updated_at":"2020-03-06T12:22:14.000+09:00","args":{}},{"id":26,"platform":"web_desktop","page":"search","inventory":"card_list","sizes":[[728,90]],"tag":"/395211568/production/desktop-web.search.contents.atf","enabled":true,"created_at":"2017-06-23T02:00:52.000+09:00","updated_at":"2017-06-23T02:00:52.000+09:00","args":{"start":{"value":0}}},{"id":29,"platform":"web_mobile","page":"search","inventory":"card_list","sizes":[[320,100]],"tag":"/395211568/production/mobile-web.search.contents.atf","enabled":true,"created_at":"2017-06-23T02:01:27.000+09:00","updated_at":"2017-06-23T02:01:28.000+09:00","args":{"start":{"value":0}}},{"id":30,"platform":"web_mobile","page":"search","inventory":"card_list_btf","sizes":[[320,100]],"tag":"/395211568/production/mobile-web.search.contents.btf","enabled":true,"created_at":"2017-06-23T02:01:36.000+09:00","updated_at":"2017-06-23T02:01:37.000+09:00","args":{"start":{"value":8}}},{"id":46,"platform":"web_desktop","page":"search","inventory":"card_list_btf","sizes":[[728,90]],"tag":"/395211568/production/desktop-web.search.contents.btf","enabled":true,"created_at":null,"updated_at":null,"args":{"start":{"value":8}}}]</script>
# <script id="dfp_targeting" type="application/json">{"key":"동작구"}</script>
# </link></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body ng-app="mp20App" onunload="">
# <script charset="utf-8" id="search_first_result_json" type="application/json">[{&quot;restaurant&quot;:{&quot;restaurant_uuid&quot;:406312,&quot;cusine_code&quot;:4,&quot;subcusine_code&quot;:16,&quot;region_code&quot;:1,&quot;metro_code&quot;:16,&quot;price_range_code&quot;:2,&quot;latitude&quot;:&quot;37.4805575&quot;,&quot;longitude&quot;:&quot;126.9806905&quot;,&quot;status_code&quot;:1,&quot;phone_number&quot;:&quot;02-597-1987&quot;,&quot;phone1&quot;:&quot;02-597-1987&quot;,&quot;is_verified&quot;:1,&quot;name&quot;:&quot;작은피자집&quot;,&quot;branch_name&quot;:&quot;&quot;,&quot;address&quot;:&quot;서울시 동작구 사당동 1029-37&quot;,&quot;road_address&quot;:&quot;서울특별시 동작구 사당로30길 96&quot;,&quot;building_name&quot;:&quot;&quot;,&quot;floor&quot;:&quot;&quot;,&quot;restaurant_key&quot;:&quot;A2wHyagv8QkV&quot;,&quot;web_url&quot;:&quot;https://www.mangoplate.com/restaurants/A2wHyagv8QkV&quot;,&quot;review_count&quot;:45,&quot;comment_count&quot;:45,&quot;picture_count&quot;:110,&quot;view_count&quot;:90426,&quot;beenhere_count&quot;:45,&quot;wannago_count&quot;:1992,&quot;checkin_count&quot;:94,&quot;rating&quot;:4.7,&quot;official_rating_available&quot;:1,&quot;full_address&quot;:&quot;서울시 동작구 사당동 1029-37&quot;,&quot;full_road_address&quot;:&quot;서울특별시 동작구 사당로30길 96&quot;,&quot;full_origin_address&quot;:&quot;&quot;,&quot;full_origin_road_address&quot;:&quot;&quot;,&quot;picture_url&quot;:&quot;https://mp-seoul-image-production-s3.mangoplate.com/1861537_1609661398822165.jpg&quot;,&quot;pic_domain&quot;:&quot;https://mp-seoul-image-production-s3.mangoplate.com&quot;,&quot;pic_key&quot;:&quot;1861537_1609661398822165.jpg&quot;,&quot;distance&quot;:0},&quot;action&quot;:null,&quot;wanna_go_count&quot;:1992,&quot;been_here_count&quot;:45,&quot;view_count&quot;:90426,&quot;review_count&quot;:45,&quot;review_char_7_count&quot;:45,&quot;rating&quot;:4.7,&quot;official_rating_available&quot;:1,&quot;eat_deal_badge_url&quot;:null,&quot;features&quot;:[],&quot;wannago_memo&quot;:null,&quot;is_in_my_list&quot;:false},{&quot;restaurant&quot;:{&quot;restaurant_uuid&quot;:202188,&quot;cusine_code&quot;:1,&quot;subcusine_code&quot;:5,&quot;region_code&quot;:1,&quot;metro_code&quot;:16,&quot;price_range_code&quot;:3,&quot;latitude&quot;:&quot;37.50810367&quot;,&quot;longitude&quot;:&quot;126.94032295&quot;,&quot;status_code&quot;:1,&quot;phone_number&quot;:&quot;02-815-2850&quot;,&quot;phone1&quot;:&quot;02-815-2850&quot;,&quot;is_verified&quot;:1,&quot;name&quot;:&quot;운봉산장양고기전문점&quot;,&quot;branch_name&quot;:&quot;&quot;,&quot;address&quot;:&quot;서울시 동작구 노량진동 309-18&quot;,&quot;road_address&quot;:&quot;서울특별시 동작구 장승배기로 118-1&quot;,&quot;building_name&quot;:&quot;&quot;,&quot;floor&quot;:&quot;&quot;,&quot;restaurant_key&quot;:&quot;H7qgftiPmv&quot;,&quot;web_url&quot;:&quot;https://www.mangoplate.com/restaurants/H7qgftiPmv&quot;,&quot;review_count&quot;:37,&quot;comment_count&quot;:37,&quot;picture_count&quot;:122,&quot;view_count&quot;:47495,&quot;beenhere_count&quot;:37,&quot;wannago_count&quot;:885,&quot;checkin_count&quot;:53,&quot;rating&quot;:4.6,&quot;official_rating_available&quot;:1,&quot;full_address&quot;:&quot;서울시 동작구 노량진동 309-18&quot;,&quot;full_road_address&quot;:&quot;서울특별시 동작구 장승배기로 118-1&quot;,&quot;full_origin_address&quot;:&quot;&quot;,&quot;full_origin_road_address&quot;:&quot;&quot;,&quot;picture_url&quot;:&quot;https://mp-seoul-image-production-s3.mangoplate.com/202188/1656652_1633947355715_42022&quot;,&quot;pic_domain&quot;:&quot;https://mp-seoul-image-production-s3.mangoplate.com&quot;,&quot;pic_key&quot;:&quot;202188/1656652_1633947355715_42022&quot;,&quot;distance&quot;:0},&quot;action&quot;:null,&quot;wanna_go_count&quot;:885,&quot;been_here_count&quot;:37,&quot;view_count&quot;:47495,&quot;review_count&quot;:37,&quot;review_char_7_count&quot;:37,&quot;rating&quot;:4.6,&quot;official_rating_available&quot;:1,&quot;eat_deal_badge_url&quot;:null,&quot;features&quot;:[],&quot;wannago_memo&quot;:null,&quot;is_in_my_list&quot ...
# <!-- 본문 영역 -->
# <main class="pg-search" data-keyword="동작구" ng-controller="mp20_search_result_controller">
# <article class="contents">
# <div class="black_screen"></div>
# <!-- 데스크탑 컨텐츠 영역 -->
# <div class="column-wrapper">
# <div class="column-contents flex-contents"><!-- 검색결과 식당 리스트 flex로 변경 -->
# <div class="inner">
# <!-- 검색 식당 목록 -->
# <section class="module search-results short-bottom">
# <div class="search_info">
# <div class="search-options" ng-class="{is_empty_result: search_result_list.length === 0}">
# <button class="btn filter" data-background_url="https://d1jrqqyoo3n46w.cloudfront.net/web/resources/prwed8gjtoikxz6h.png" data-btn_msg="앱에서 입맛대로 검색하기" data-event_name_a="CLICK_DWN_FILTER_W1" data-event_name_b="CLICK_DWN_FILTER_W2" data-message_a="망고플레이트 &lt;strong class='strong'&gt;최신 버전 앱&lt;/strong&gt;에서&lt;br /&gt;사용할 수 있는 기능입니다." data-message_b="망고플레이트 &lt;strong class='strong'&gt;최신 버전 앱&lt;/strong&gt;에서&lt;br /&gt;사용할 수 있는 기능입니다." data-page_name="PU_DWN_FILTER" ng-class="{selected: is_apply_filter}" ng-click="open_filter()" onclick="trackEvent('CLICK_FILTER')">필터</button>
# <button class="btn map" data-background_url="https://d1jrqqyoo3n46w.cloudfront.net/web/resources/ywyf4p824puyfxqf.png" data-btn_msg="앱에서 지도보기" data-event_name_a="CLICK_DWN_MAP_W1" data-event_name_b="CLICK_DWN_MAP_W2" data-message_a="망고플레이트 앱에서 사용하실 수 있는 기능입니다." data-message_b="망고플레이트 앱에서 편리하게 맛집 지도를 확인해보세요!" data-page_name="PU_DWN_MAP" onclick="trackEvent('CLICK_MAP')">지도</button>
# </div>
# <div class="search_top_title_wrap">
# <div class="title_wrap">
# <h1 class="title" ng-show="search_result_list.length">동작구 맛집 인기 검색순위</h1>
# </div>
# </div>
# </div>
# <div class="RelatedContentSlider__Wrap" ng-class="{'RelatedContentSlider__Wrap--Loaded': relatedContentLoaded &amp;&amp; relatedContents &amp;&amp; relatedContents.length &gt; 0}" ng-hide="relatedContentLoaded &amp;&amp; relatedContents &amp;&amp; relatedContents.length === 0">
# <div class="LoadingPlaceholder RelatedContentSlider__LoadingBar" ng-hide="relatedContentLoaded">
# <ul class="LoadingPlaceholder__Dots">
# <li class="LoadingPlaceholder__Dot"></li>
# <li class="LoadingPlaceholder__Dot"></li>
# <li class="LoadingPlaceholder__Dot"></li>
# </ul>
# </div>
# <related-content-slider handle-click-related-content="handleClickRelatedContent" is-eat-deal-collection-type="isEatDealCollectionType" keyword="keyword" ng-cloak="" related-contents="relatedContents">
# </related-content-slider>
# </div>
# <div class="search-list-restaurants-inner-wrap">
# <div class="search_loading_gray_layer" ng-cloak="" ng-show="ajaxing"></div>
# <ul class="list-restaurants">
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="16">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/A2wHyagv8QkV" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:0,&quot;restaurant_key&quot;:[&quot;A2wHyagv8QkV&quot;]})">
# <div class="thumb">
# <img alt="작은피자집 사진 - 서울시 동작구 사당동 1029-37" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/1861537_1609661398822165.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/A2wHyagv8QkV">
# <h2 class="title">작은피자집
# </h2>
# </a>
# <strong class="point search_point ">4.7</strong>
# <p class="etc">동작/사당 - <span>기타 양식</span></p>
# <p class="etc_info">
# <span class="view_count">90,426</span>
# <span class="review_count">45</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="5">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/H7qgftiPmv" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:0,&quot;restaurant_key&quot;:[&quot;H7qgftiPmv&quot;]})">
# <div class="thumb">
# <img alt="운봉산장양고기전문점 사진 - 서울시 동작구 노량진동 309-18" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/202188/1656652_1633947355715_42022?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/H7qgftiPmv">
# <h2 class="title">운봉산장양고기전문점
# </h2>
# </a>
# <strong class="point search_point ">4.6</strong>
# <p class="etc">동작/사당 - <span>고기 요리</span></p>
# <p class="etc_info">
# <span class="view_count">47,495</span>
# <span class="review_count">37</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="31">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/0D-yLUXut2C6" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:1,&quot;restaurant_key&quot;:[&quot;0D-yLUXut2C6&quot;]})">
# <div class="thumb">
# <img alt="렁트멍 사진 - 서울시 동작구 상도동 416" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/added_restaurants/67078_1467633451451579.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/0D-yLUXut2C6">
# <h2 class="title">렁트멍
# </h2>
# </a>
# <strong class="point search_point ">4.5</strong>
# <p class="etc">동작/사당 - <span>베이커리</span></p>
# <p class="etc_info">
# <span class="view_count">143,999</span>
# <span class="review_count">69</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="40">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/8bMnQH_r40am" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:1,&quot;restaurant_key&quot;:[&quot;8bMnQH_r40am&quot;]})">
# <div class="thumb">
# <img alt="올라아보 사진 - 서울시 동작구 사당동 147-29" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/1055267_1563020250050297.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/8bMnQH_r40am">
# <h2 class="title">올라아보
# </h2>
# </a>
# <strong class="point search_point ">4.5</strong>
# <p class="etc">동작/사당 - <span>남미 음식</span></p>
# <p class="etc_info">
# <span class="view_count">77,080</span>
# <span class="review_count">69</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="6">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/drXX2BDsGZ" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:2,&quot;restaurant_key&quot;:[&quot;drXX2BDsGZ&quot;]})">
# <div class="thumb">
# <img alt="형제상회 사진 - 서울시 동작구 노량진동 13-8" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/1704015_1611240442852430.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/drXX2BDsGZ">
# <h2 class="title">형제상회
#                                     <span class="branch">(노량진본점)</span>
# </h2>
# </a>
# <strong class="point search_point ">4.4</strong>
# <p class="etc">동작/사당 - <span>해산물 요리</span></p>
# <p class="etc_info">
# <span class="view_count">414,446</span>
# <span class="review_count">111</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="30">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/RztxiJSWE4" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:2,&quot;restaurant_key&quot;:[&quot;RztxiJSWE4&quot;]})">
# <div class="thumb">
# <img alt="페니힐스커피스테이션 사진 - 서울시 동작구 사당동 1042-13" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/added_restaurants/526930_1466961114389005.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/RztxiJSWE4">
# <h2 class="title">페니힐스커피스테이션
# </h2>
# </a>
# <strong class="point search_point ">4.4</strong>
# <p class="etc">동작/사당 - <span>카페 / 디저트</span></p>
# <p class="etc_info">
# <span class="view_count">100,831</span>
# <span class="review_count">94</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="18">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/mseYsQL8gXuC" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:3,&quot;restaurant_key&quot;:[&quot;mseYsQL8gXuC&quot;]})">
# <div class="thumb">
# <img alt="김씨마구로 사진 - 서울시 동작구 노량진동 13-6" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/915425_1571496981687341.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/mseYsQL8gXuC">
# <h2 class="title">김씨마구로
# </h2>
# </a>
# <strong class="point search_point ">4.4</strong>
# <p class="etc">동작/사당 - <span>회 / 스시</span></p>
# <p class="etc_info">
# <span class="view_count">67,955</span>
# <span class="review_count">20</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="22">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/prl1JPZOWqag" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:3,&quot;restaurant_key&quot;:[&quot;prl1JPZOWqag&quot;]})">
# <div class="thumb">
# <i class="featured_badge" style="background-image: url('https://mp-seoul-image-production-s3.mangoplate.com/badge_pictures/r-i0n1w_hdfo4vlf.png')"></i>
# <img alt="오꼬노미스토리 사진 - 서울시 동작구 노량진동 256-61" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/538728_1608802270896998.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/prl1JPZOWqag">
# <h2 class="title">오꼬노미스토리
# </h2>
# </a>
# <strong class="point search_point ">4.4</strong>
# <p class="etc">동작/사당 - <span>철판 요리</span></p>
# <p class="etc_info">
# <span class="view_count">36,565</span>
# <span class="review_count">21</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="30">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/hJd3wPlT-Hk_" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:4,&quot;restaurant_key&quot;:[&quot;hJd3wPlT-Hk_&quot;]})">
# <div class="thumb">
# <img alt="오다가다 사진 - 서울시 동작구 사당동 39-10" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/added_restaurants/619788_1493656593003647.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/hJd3wPlT-Hk_">
# <h2 class="title">오다가다
# </h2>
# </a>
# <strong class="point search_point ">4.3</strong>
# <p class="etc">동작/사당 - <span>카페 / 디저트</span></p>
# <p class="etc_info">
# <span class="view_count">120,408</span>
# <span class="review_count">84</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="6">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/K1lhL2EtJRt8" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:4,&quot;restaurant_key&quot;:[&quot;K1lhL2EtJRt8&quot;]})">
# <div class="thumb">
# <img alt="독도수산 사진 - 서울시 동작구 노량진동 13-6" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/858516_1532672675396340.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/K1lhL2EtJRt8">
# <h2 class="title">독도수산
# </h2>
# </a>
# <strong class="point search_point ">4.3</strong>
# <p class="etc">동작/사당 - <span>해산물 요리</span></p>
# <p class="etc_info">
# <span class="view_count">25,947</span>
# <span class="review_count">18</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="18">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/u_FH24C5Kc" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:5,&quot;restaurant_key&quot;:[&quot;u_FH24C5Kc&quot;]})">
# <div class="thumb">
# <img alt="가네끼스시 사진 - 서울시 동작구 신대방동 395-69" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/59951/458314_1452396027898_3637?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/u_FH24C5Kc">
# <h2 class="title">가네끼스시
# </h2>
# </a>
# <strong class="point search_point expected">4.3</strong>
# <p class="etc">동작/사당 - <span>회 / 스시</span></p>
# <p class="etc_info">
# <span class="view_count">29,605</span>
# <span class="review_count">11</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="5">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/NlrcpMeHFOzg" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:5,&quot;restaurant_key&quot;:[&quot;NlrcpMeHFOzg&quot;]})">
# <div class="thumb">
# <img alt="다독이네 숯불구이 사진 - 서울시 동작구 노량진동 40-34" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/1560646_1584960829459212.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/NlrcpMeHFOzg">
# <h2 class="title">다독이네 숯불구이
# </h2>
# </a>
# <strong class="point search_point ">4.3</strong>
# <p class="etc">동작/사당 - <span>고기 요리</span></p>
# <p class="etc_info">
# <span class="view_count">23,836</span>
# <span class="review_count">24</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="34">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/dFjEJPa93yJf" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:6,&quot;restaurant_key&quot;:[&quot;dFjEJPa93yJf&quot;]})">
# <div class="thumb">
# <img alt="정작가의 막걸리집 사진 - 서울시 동작구 사당동 89-1" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/335554/26049_1507858518893_20367?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/dFjEJPa93yJf">
# <h2 class="title">정작가의 막걸리집
# </h2>
# </a>
# <strong class="point search_point expected">4.3</strong>
# <p class="etc">동작/사당 - <span>전통 주점 / 포차</span></p>
# <p class="etc_info">
# <span class="view_count">22,141</span>
# <span class="review_count">14</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="3">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/yhLPJnTWt17m" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:6,&quot;restaurant_key&quot;:[&quot;yhLPJnTWt17m&quot;]})">
# <div class="thumb">
# <img alt="서평면옥 사진 - 서울시 동작구 신대방동 395-70" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/419384/897636_1622004710082_46867?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/yhLPJnTWt17m">
# <h2 class="title">서평면옥
# </h2>
# </a>
# <strong class="point search_point ">4.3</strong>
# <p class="etc">동작/사당 - <span>국수 / 면 요리</span></p>
# <p class="etc_info">
# <span class="view_count">9,960</span>
# <span class="review_count">13</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="6">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/sBb2ypsWeE" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:7,&quot;restaurant_key&quot;:[&quot;sBb2ypsWeE&quot;]})">
# <div class="thumb">
# <img alt="전라상회 사진 - 서울시 동작구 노량진동 13-8" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/37926/533108_1461687704704_722255?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/sBb2ypsWeE">
# <h2 class="title">전라상회
# </h2>
# </a>
# <strong class="point search_point ">4.3</strong>
# <p class="etc">동작/사당 - <span>해산물 요리</span></p>
# <p class="etc_info">
# <span class="view_count">41,085</span>
# <span class="review_count">22</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="4">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/oWZ4cQgJ7FPV" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:7,&quot;restaurant_key&quot;:[&quot;oWZ4cQgJ7FPV&quot;]})">
# <div class="thumb">
# <img alt="재팔이네닭발 사진 - 서울시 동작구 흑석동 43-3" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/908198_1583340407427197.jpg?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/oWZ4cQgJ7FPV">
# <h2 class="title">재팔이네닭발
# </h2>
# </a>
# <strong class="point search_point expected">4.3</strong>
# <p class="etc">동작/사당 - <span>닭 / 오리 요리</span></p>
# <p class="etc_info">
# <span class="view_count">17,847</span>
# <span class="review_count">17</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="6">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/1OVrnWYkmikK" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:8,&quot;restaurant_key&quot;:[&quot;1OVrnWYkmikK&quot;]})">
# <div class="thumb">
# <img alt="대박 사진 - 서울시 동작구 흑석동 181-15" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/352220/881009_1589027955383_9832?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/1OVrnWYkmikK">
# <h2 class="title">대박
# </h2>
# </a>
# <strong class="point search_point expected">4.3</strong>
# <p class="etc">동작/사당 - <span>해산물 요리</span></p>
# <p class="etc_info">
# <span class="view_count">7,899</span>
# <span class="review_count">11</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="2">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/hVLHSCT8aE" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:8,&quot;restaurant_key&quot;:[&quot;hVLHSCT8aE&quot;]})">
# <div class="thumb">
# <img alt="가마솥손두부 사진 - 서울시 동작구 사당동 1041-7" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/78652_1438089588662?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/hVLHSCT8aE">
# <h2 class="title">가마솥손두부
# </h2>
# </a>
# <strong class="point search_point expected">4.3</strong>
# <p class="etc">동작/사당 - <span>탕 / 찌개 / 전골</span></p>
# <p class="etc_info">
# <span class="view_count">3,842</span>
# <span class="review_count">6</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <li class="list-restaurant server_render_search_result_item">
# <div class="list-restaurant-item" data-subcusine_code="18">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/lVwSxatR9MQq" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:9,&quot;restaurant_key&quot;:[&quot;lVwSxatR9MQq&quot;]})">
# <div class="thumb">
# <img alt="초와밥 사진 - 서울시 동작구 사당동 1031-13" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/254876/536752_1464509561924_9757?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/lVwSxatR9MQq">
# <h2 class="title">초와밥
# </h2>
# </a>
# <strong class="point search_point ">4.2</strong>
# <p class="etc">동작/사당 - <span>회 / 스시</span></p>
# <p class="etc_info">
# <span class="view_count">171,705</span>
# <span class="review_count">115</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="list-restaurant-item" data-subcusine_code="6">
# <figure class="restaurant-item">
# <a class="only-desktop_not" href="/restaurants/hxvT6OzhZLrb" onclick="trackEvent('CLICK_RESTAURANT', {&quot;position&quot;:9,&quot;restaurant_key&quot;:[&quot;hxvT6OzhZLrb&quot;]})">
# <div class="thumb">
# <img alt="사당광안리 사진 - 서울시 동작구 사당동 1031-37" class="center-croping lazy" data-error="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80" data-original="https://mp-seoul-image-production-s3.mangoplate.com/234388/259765_1504082915416_26124?fit=around|359:240&amp;crop=359:240;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </div>
# </a>
# <figcaption>
# <div class="info">
# <a href="/restaurants/hxvT6OzhZLrb">
# <h2 class="title">사당광안리
# </h2>
# </a>
# <strong class="point search_point ">4.2</strong>
# <p class="etc">동작/사당 - <span>해산물 요리</span></p>
# <p class="etc_info">
# <span class="view_count">61,486</span>
# <span class="review_count">24</span>
# </p>
# </div>
# </figcaption>
# </figure>
# </div>
# <div class="adview_server_render_search_result_item"></div>
# </li>
# <search-item ng-repeat="restaurant_pair in search_result_list" ng-show="!is_first_search_result" picture-lebel="사진"></search-item>
# </ul>
# </div>
# <div class="paging-container" ng-cloak="" ng-hide="!search_result_list.length &amp;&amp; !ajaxing">
# <p class="paging">
# <a href="#" ng-class="{selected: $index + 1 == page}" ng-click="get_next_page($index + 1)" ng-repeat="paging in get_paging_array(search_all_count) | limitTo: max_page track by $index" onclick="trackEvent('CLICK_SEARCH_PAGE'); return false;">{{::$index + 1}}</a>
# </p>
# </div>
# <div class="search_result_empty_message" ng-cloak="" ng-show="!search_result_list.length &amp;&amp; !ajaxing">
# <p class="search_result_empty_message_title" ng-show="!move_search">
# <span class="mango_text">'동작구'</span>에 대한 검색 결과가 없습니다.
#               </p>
# <p class="search_result_empty_message_title" ng-show="move_search">
#                 지도 내 검색에 대한 검색 결과가 없습니다.
#               </p>
# <div class="search_result_empty_message_content">
# <p class="mango_text search_result_empty_message_content_sub_title">검색한 식당이 망고플레이트에 보이지 않을 땐??</p>
# <ul class="search_result_empty_message_content_list">
# <li>1. 망고플레이트 모바일 앱을 설치한다</li>
# <li>2. ‘+’버튼을 눌러 식당 등록하기를 터치!</li>
# <li>3. 등록할 식당의 정보를 입력한 후 등록 완료!</li>
# </ul>
# </div>
# </div>
# <div class="dfp_ad_paging_bottom"></div>
# </section>
# </div>
# <aside class="popup search-filter">
# <div class="inner">
# <div>
# <!--<legend>검색 필터</legend>-->
# <div class="filter-item">
# <label for="sorting01">검색 필터</label>
# <p class="order_wrap">
# <input id="sorting01" name="sorting" ng-checked="is_checked_sorting_value(2)" type="radio" value="2"/><label data-filter="2" for="sorting01" ng-click="set_temp_offset($event)" onclick="trackEvent('CLICK_ORDER_BY_RATING')">평점순</label>
# <input id="sorting02" name="sorting" ng-checked="is_checked_sorting_value(0)" type="radio" value="0"/><label data-filter="0" for="sorting02" ng-click="set_temp_offset($event)" onclick="trackEvent('CLICK_ORDER_BY_POPULARITY')">인기순</label>
# </p>
# </div>
# <div class="filter-item">
# <span class="options">중복 선택 가능</span>
# <label for="">가격/1인당</label>
# <p class="cost_wrap">
# <input class="cost" data-value="1" id="cost01" name="cost" ng-checked="is_checked_price_value(price_filter_name, 1)" type="checkbox"/><label class="cost01 cost-zoom" data-filter="1" for="cost01" ng-click="set_filter_value(price_filter_name, $event, price_filter_value_hadler)" onclick="trackEvent('CLICK_PRICE_1')"><span>만원미만</span></label>
# <input class="cost" data-value="2" id="cost02" name="cost" ng-checked="is_checked_price_value(price_filter_name, 2)" type="checkbox"/><label class="cost02 cost-zoom" data-filter="2" for="cost02" ng-click="set_filter_value(price_filter_name, $event, price_filter_value_hadler)" onclick="trackEvent('CLICK_PRICE_2')"><span>1만원대</span></label>
# <input class="cost" data-value="3" id="cost03" name="cost" ng-checked="is_checked_price_value(price_filter_name, 3)" type="checkbox"/><label class="cost03 cost-zoom" data-filter="3" for="cost03" ng-click="set_filter_value(price_filter_name, $event, price_filter_value_hadler)" onclick="trackEvent('CLICK_PRICE_3')"><span>2만원대</span></label>
# <input class="cost" data-value="4" id="cost04" name="cost" ng-checked="is_checked_price_value(price_filter_name, 4)" type="checkbox"/><label class="cost04 cost-zoom" data-filter="4,5" for="cost04" ng-click="set_filter_value(price_filter_name, $event, price_filter_value_hadler)" onclick="trackEvent('CLICK_PRICE_4')"><span>3만원대</span></label>
# </p>
# </div>
# <div class="filter-item only-desktop">
# <span class="options">중복 선택 가능</span>
# <label for="">지역</label>
# <p class="region" ng-cloak="">
# <a data-filter="{{::region_item.type_value}}" href="#" ng-bind="region_item.display_text" ng-class="{selected: filter_cuisine_value == region_item.type_value}" ng-click="selected_region($event)" ng-repeat="region_item in filter_region_list | limitTo: filter_region_list_length" onclick="trackEvent('CLICK_LOCATION'); return false;"></a>
# <a class="more" href="#" ng-click="show_filter_more_region()" onclick="trackEvent('CLICK_LOCATION'); return false;">더보기</a>
# </p>
# <p class="metro">
# <span class="metro_btn" ng-repeat="metro_item in filter_metro_list">
# <input data-value="{{::metro_item.type_value}}" id="region01_0{{::$index + 1}}" name="region" ng-checked="is_checked_filter_value(metro_filter_name, metro_item.type_value)" type="checkbox">
# <label class="small" data-filter="{{::metro_item.type_value}}" for="region01_0{{::$index + 1}}" ng-click="set_filter_value(metro_filter_name, $event, default_filter_value_hadler)" onclick="trackEvent('CLICK_LOCATION')">
# <span data-filter="{{::metro_item.type_value}}" ng-bind="metro_item.display_text"></span>
# </label>
# </input></span>
# <!--<button class="btn-region-more">지역 더보기</button>-->
# <div class="btn-region-cancel_wrap" ng-class="{visible: is_metro_filter_on()}">
# <button class="btn-region-cancel" ng-click="reset_metro()">전체 선택 취소</button>
# </div>
# </p>
# <div class="more-region">
# <a data-filter="{{::region_item.type_value}}" href="#" ng-class="{selected: filter_cuisine_value == region_item.type_value}" ng-click="selected_region($event)" ng-repeat="region_item in filter_region_list" ng-show="$index + 1 &gt; filter_region_list_length" onclick="trackEvent('CLICK_LOCATION');return false;">{{::region_item.display_text}}</a>
# </div>
# </div>
# <div class="filter-item only-desktop">
# <span class="options">중복 선택 가능</span>
# <label for="">음식종류</label>
# <p class="cuisine_list_wrap">
# <input class="food" data-value="1" id="food01" name="food" ng-checked="is_checked_filter_value(cusine_filter_name, 1)" type="checkbox"/><label class="food01" data-filter="1" for="food01" ng-click="set_filter_value(cusine_filter_name, $event, default_filter_value_hadler)">한식</label>
# <input class="food" data-value="3" id="food02" name="food" ng-checked="is_checked_filter_value(cusine_filter_name, 3)" type="checkbox"/><label class="food02" data-filter="3" for="food02" ng-click="set_filter_value(cusine_filter_name, $event, default_filter_value_hadler)">일식</label>
# <input class="food" data-value="2" id="food03" name="food" ng-checked="is_checked_filter_value(cusine_filter_name, 2)" type="checkbox"/><label class="food03" data-filter="2" for="food03" ng-click="set_filter_value(cusine_filter_name, $event, default_filter_value_hadler)">중식</label>
# <input class="food" data-value="4" id="food04" name="food" ng-checked="is_checked_filter_value(cusine_filter_name, 4)" type="checkbox"/><label class="food04 line-break" data-filter="4" for="food04" ng-click="set_filter_value(cusine_filter_name, $event, default_filter_value_hadler)">양식</label>
# <input class="food" data-value="5" id="food05" name="food" ng-checked="is_checked_filter_value(cusine_filter_name, 5)" type="checkbox"/><label class="food05" data-filter="5" for="food05" ng-click="set_filter_value(cusine_filter_name, $event, default_filter_value_hadler)">세계음식</label>
# <input class="food" data-value="6" id="food06" name="food" ng-checked="is_checked_filter_value(cusine_filter_name, 6)" type="checkbox"/><label class="food06" data-filter="6" for="food06" ng-click="set_filter_value(cusine_filter_name, $event, default_filter_value_hadler)">뷔페</label>
# <input class="food" data-value="7" id="food07" name="food" ng-checked="is_checked_filter_value(cusine_filter_name, 7)" type="checkbox"/><label class="food07" data-filter="7" for="food07" ng-click="set_filter_value(cusine_filter_name, $event, default_filter_value_hadler)">카페</label>
# <input class="food" data-value="8" id="food08" name="food" ng-checked="is_checked_filter_value(cusine_filter_name, 8)" type="checkbox"/><label class="food08 line-break" data-filter="8" for="food08" ng-click="set_filter_value(cusine_filter_name, $event, default_filter_value_hadler)">주점</label>
# </p>
# </div>
# <div class="filter-item only-desktop">
# <label for="parking01">주차</label>
# <p>
# <input id="parking01" name="parking" ng-checked="is_checked_parking_value(0)" type="radio" value="0"/><label data-filter="0" for="parking01" ng-click="set_filter_value(parking_filter_name, $event, default_filter_value_hadler)"> 상관없음</label>
# <input id="parking02" name="parking" ng-checked="is_checked_parking_value(1)" type="radio" value="1"/><label data-filter="1" for="parking02" ng-click="set_filter_value(parking_filter_name, $event, default_filter_value_hadler)">가능한 곳만</label>
# </p>
# </div>
# </div>
# <!-- 앱으로 연결 -->
# <aside class="connect-mp-app" style="background-image: url('https://d1jrqqyoo3n46w.cloudfront.net/web/resources/prwed8gjtoikxz6h.png')">
# <div class="inner">
# <p>앱에서 검색하기</p>
# <p class="icon">
# <img alt="망고플레이트 아이콘" src="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/gc6axol9tbyfjkj-.png?fit=around|*:*&amp;crop=*:*;*,*&amp;output-format=jpg&amp;output-quality=80"/>
# </p>
# <p>망고플레이트 앱에서 모든 필터로 간편하게 맛집들을 검색해보세요!</p>
# <a class="btn-shortcut-app" data-event_name="CLICK_DWN_POPUPFILTER_W1" data-event_term="V1" href="#" onclick="trackEvent('CLICK_DWN_POPUPFILTER_W1'); go_to_app_or_market(this);return false;">앱에서 입맛대로 검색하기</a>
# </div>
# </aside>
# </div>
# <div class="submit-container">
# <button class="btn cancel" ng-click="close_filter_button()" onclick="trackEvent('CLICK_CLOSE_FILTER')">취소</button>
# <button class="btn submit" ng-click="do_filter_search()" onclick="trackEvent('CLICK_FILTER_APPLY')" type="submit" value="">적용</button>
# </div>
# </aside>
# </div> <!-- class="column-contents" -->
# </div>
# <div class="column-back only-desktop"></div>
# <!-- 데스크탑 사이드 영역 -->
# <div class="column-side">
# <!-- 지도 -->
# <div class="map-container_wrap">
# <div class="map-container">
# </div>
# <button class="btn-map" ng-click="change_map_mode()" ng-cloak="">{{map_size_btn_message}}</button>
# <div class="map_black_screen" ng-show="!search_result_list.length &amp;&amp; !ajaxing"></div>
# <button class="btn-type-round reset" ng-class="{show_reset_btn: move_map}" ng-click="move_map_search(true)">이 지역 검색하기</button><!-- 지도영역에서 노출 안되므로 위로 올림-->
# <p class="reset no_result" ng-class="{show_no_result: (!search_result_list.length &amp;&amp; !ajaxing)}">검색 결과가 없어요</p>
# </div>
# <div class="inner">
# <div class="column-module">
# <pagination-type-mobile is-active-first-button="page &gt; 2" is-active-next-button="last_page &gt; page &amp;&amp; max_page &gt; page" is-active-prev-button="page &gt; 1" last-page="last_page" on-click-first="handleClickFirstPaginationButton" on-click-next="handleClickNextPaginationButton" on-click-prev="handleClickPrevPaginationButton" page="page">
# </pagination-type-mobile>
# <!-- 리스트 -->
# <section class="module related-list only-desktop" ng-cloak="" ng-show="relatedContentLoaded &amp;&amp; relatedContents &amp;&amp; relatedContents.length &gt; 0">
# <span class="title">관련 콘텐츠</span>
# <ul class="list-type-ls">
# ...
# <span class="Menu__NavText">EAT딜</span>
# </a>
# </li>
# <li class="Menu__NavItem Menu__NavItem--Hide">
# <div class="Menu__NavLink Menu__LoginButton">
# <span class="Menu__NavText">로그인</span>
# </div>
# </li>
# <li class="Menu__NavItem Menu__NavItem--Hide">
# <div class="Menu__NavLink Menu__LogoutButton">
# <span class="Menu__NavText">로그아웃</span>
# </div>
# </li>
# <li class="Menu__NavItem">
# <div class="Menu__NavLink Menu__toAppButton">
# <span class="Menu__NavText">앱에서 보기</span>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# <div class="ad_placeholder" data-inventory="all" data-page="init" data-platform="web_desktop"></div>
# <div class="ad_placeholder" data-inventory="all" data-page="init" data-platform="web_mobile"></div>
# <!-- 하단 영역 -->
# <footer class="footer">
# <div class="inner">
# <div class="mp_logo">
# <a class="btn-mp" href="/">
# <img alt="mangoplate logo" class="mp_logo_img" src="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/mangoplate-gray-logo.svg"/>
# </a>
# <p class="subtitle">Eat, Share, Be Happy.</p>
# </div>
# <button class="btn-mp-app" data-event_name="CLICK_DOWNLOAD_BOTTOM_DEFAULT" data-event_term="V1" onclick="trackEvent('CLICK_DOWNLOAD_BOTTOM_DEFAULT'); go_to_app_or_market(this);">
#       망고플레이트 앱에서 열기
#     </button>
# <p class="sns-shortcut">
# <a class="btn facebook" href="https://www.facebook.com/mangoplate" onclick="trackEvent('CLICK_SHARE_FACEBOOK');" target="_blank">
#         망고플레이트 페이스북 계정으로 바로가기
#       </a>
# <a class="btn instagram" href="https://instagram.com/mangoplate/" onclick="trackEvent('CLICK_SHARE_INSTA');" target="_blank">
#         망고플레이트 인스타그램 계정으로 바로가기
#       </a>
# </p>
# <nav class="links-external">
# <ul class="list-links">
# <li>
# <a href="/company">
#               회사소개
#             </a>
# </li>
# <li>
# <a href="/careers">
#               망고플레이트 채용
#             </a>
# </li>
# <li>
# <a href="/investment">
#                 투자 정보
#               </a>
# </li>
# <li class="only-desktop">
# <a href="/etc/download_company_ci" target="_blank">
#               브랜드 가이드라인
#             </a>
# </li>
# <li>
# <a href="https://www.mangoforbiz.com/?utm_campaign=main_bottom_business&amp;utm_medium=bizhome&amp;utm_source=web" target="_blank">
#                 망고플레이트 비즈니스
#               </a>
# </li>
# <li>
# <a href="https://www.mangoforbiz.com/?utm_campaign=20180116v1&amp;utm_medium=main_bottom_adinquiry&amp;utm_source=mp_web" target="_blank">
#               광고 문의
#             </a>
# </li>
# </ul>
# <ul class="list-links">
# <li>
# <a href="/notice" target="_blank">
#                 공지사항
#               </a>
# </li>
# <li>
# <a class="" href="/terms/contract" onclick="trackEvent('CLICK_TERMS', 'contract')" target="_blank">
#                 이용약관
#               </a>
# </li>
# <li>
# <a class="" href="/terms/contract_non_signup" onclick="trackEvent('CLICK_TERMS', 'contract_non_signup')" target="_blank">
#                 비회원 이용자 이용정책
#               </a>
# </li>
# <li>
# <a class="bold" href="/terms/privacy" onclick="trackEvent('CLICK_TERMS', 'privacy')" target="_blank">
#                 개인정보처리방침
#               </a>
# </li>
# <li>
# <a class="" href="/terms/location" onclick="trackEvent('CLICK_TERMS', 'location')" target="_blank">
#                 위치기반서비스 이용약관
#               </a>
# </li>
# <li>
# <a class="" href="/terms/community_guidelines" onclick="trackEvent('CLICK_TERMS', 'community_guidelines')" target="_blank">
#                 커뮤니티 가이드라인
#               </a>
# </li>
# <li>
# <a class="" href="/terms/youth_protection" onclick="trackEvent('CLICK_TERMS', 'youth_protection')" target="_blank">
#                 청소년보호정책
#               </a>
# </li>
# <li>
# <a href="https://brunch.co.kr/@mangoplate/14" target="_blank">
#                 홀릭 소개
#               </a>
# </li>
# <li>
# <a href="/company#contact">
#                 문의하기
#               </a>
# </li>
# </ul>
# </nav>
# <div class="sitemap-location-keywords">
# <div class="keyword_wrap">
# <span class="keyword">인기지역 : </span>
# <a class="keyword" href="/search/이태원" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:0,&quot;keyword&quot;:&quot;이태원&quot;})" target="_blank">
#               이태원
#             </a>
#             |
#             <a class="keyword" href="/search/홍대" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:1,&quot;keyword&quot;:&quot;홍대&quot;})" target="_blank">
#               홍대
#             </a>
#             |
#             <a class="keyword" href="/search/강남역" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:2,&quot;keyword&quot;:&quot;강남역&quot;})" target="_blank">
#               강남역
#             </a>
#             |
#             <a class="keyword" href="/search/가로수길" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:3,&quot;keyword&quot;:&quot;가로수길&quot;})" target="_blank">
#               가로수길
#             </a>
#             |
#             <a class="keyword" href="/search/신촌" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:4,&quot;keyword&quot;:&quot;신촌&quot;})" target="_blank">
#               신촌
#             </a>
#             |
#             <a class="keyword" href="/search/명동" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:5,&quot;keyword&quot;:&quot;명동&quot;})" target="_blank">
#               명동
#             </a>
#             |
#             <a class="keyword" href="/search/대학로" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:6,&quot;keyword&quot;:&quot;대학로&quot;})" target="_blank">
#               대학로
#             </a>
#             |
#             <a class="keyword" href="/search/연남동" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:7,&quot;keyword&quot;:&quot;연남동&quot;})" target="_blank">
#               연남동
#             </a>
#             |
#             <a class="keyword" href="/search/부산" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:8,&quot;keyword&quot;:&quot;부산&quot;})" target="_blank">
#               부산
#             </a>
#             |
#             <a class="keyword" href="/search/합정" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:9,&quot;keyword&quot;:&quot;합정&quot;})" target="_blank">
#               합정
#             </a>
#             |
#             <a class="keyword" href="/search/대구" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:10,&quot;keyword&quot;:&quot;대구&quot;})" target="_blank">
#               대구
#             </a>
#             |
#             <a class="keyword" href="/search/여의도" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:11,&quot;keyword&quot;:&quot;여의도&quot;})" target="_blank">
#               여의도
#             </a>
#             |
#             <a class="keyword" href="/search/건대" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:12,&quot;keyword&quot;:&quot;건대&quot;})" target="_blank">
#               건대
#             </a>
#             |
#             <a class="keyword" href="/search/광화문" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:13,&quot;keyword&quot;:&quot;광화문&quot;})" target="_blank">
#               광화문
#             </a>
#             |
#             <a class="keyword" href="/search/일산" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:14,&quot;keyword&quot;:&quot;일산&quot;})" target="_blank">
#               일산
#             </a>
#             |
#             <a class="keyword" href="/search/제주" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:15,&quot;keyword&quot;:&quot;제주&quot;})" target="_blank">
#               제주
#             </a>
#             |
#             <a class="keyword" href="/search/경리단길" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:16,&quot;keyword&quot;:&quot;경리단길&quot;})" target="_blank">
#               경리단길
#             </a>
#             |
#             <a class="keyword" href="/search/한남동" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:17,&quot;keyword&quot;:&quot;한남동&quot;})" target="_blank">
#               한남동
#             </a>
#             |
#             <a class="keyword" href="/search/삼청동" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:18,&quot;keyword&quot;:&quot;삼청동&quot;})" target="_blank">
#               삼청동
#             </a>
#             |
#             <a class="keyword" href="/search/대전" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:19,&quot;keyword&quot;:&quot;대전&quot;})" target="_blank">
#               대전
#             </a>
#             |
#             <a class="keyword" href="/search/종로" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:20,&quot;keyword&quot;:&quot;종로&quot;})" target="_blank">
#               종로
#             </a>
#             |
#             <a class="keyword" href="/search/서촌" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:21,&quot;keyword&quot;:&quot;서촌&quot;})" target="_blank">
#               서촌
#             </a>
#             |
#             <a class="keyword" href="/search/잠실" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:22,&quot;keyword&quot;:&quot;잠실&quot;})" target="_blank">
#               잠실
#             </a>
#             |
#             <a class="keyword" href="/search/사당역" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:23,&quot;keyword&quot;:&quot;사당역&quot;})" target="_blank">
#               사당역
#             </a>
#             |
#             <a class="keyword" href="/search/인천" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:24,&quot;keyword&quot;:&quot;인천&quot;})" target="_blank">
#               인천
#             </a>
#             |
#             <a class="keyword" href="/search/코엑스" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:25,&quot;keyword&quot;:&quot;코엑스&quot;})" target="_blank">
#               코엑스
#             </a>
#             |
#             <a class="keyword" href="/search/상수" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:26,&quot;keyword&quot;:&quot;상수&quot;})" target="_blank">
#               상수
#             </a>
#             |
#             <a class="keyword" href="/search/서래마을" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:27,&quot;keyword&quot;:&quot;서래마을&quot;})" target="_blank">
#               서래마을
#             </a>
#             |
#             <a class="keyword" href="/search/송도" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:28,&quot;keyword&quot;:&quot;송도&quot;})" target="_blank">
#               송도
#             </a>
#             |
#             <a class="keyword" href="/search/왕십리" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:29,&quot;keyword&quot;:&quot;왕십리&quot;})" target="_blank">
#               왕십리
#             </a>
#             |
#             <a class="keyword" href="/search/분당" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:30,&quot;keyword&quot;:&quot;분당&quot;})" target="_blank">
#               분당
#             </a>
#             |
#             <a class="keyword" href="/search/혜화" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:31,&quot;keyword&quot;:&quot;혜화&quot;})" target="_blank">
#               혜화
#             </a>
#             |
#             <a class="keyword" href="/search/고속터미널" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:32,&quot;keyword&quot;:&quot;고속터미널&quot;})" target="_blank">
#               고속터미널
#             </a>
# </div>
# </div>
# <div class="language-copyrights">
# <p class="select-language">
# <a class="selected" href="/">
#           한국어
#         </a>
# <a href="/en">
#           English
#         </a>
# <a href="/zh">
#           简体中文
#         </a>
# </p>
# <small>
# <p>
#
#           ㈜ 여기어때컴퍼니<br/>서울특별시 강남구 봉은사로 479, 479타워 11층<br/>대표이사: 정명훈<br/>사업자 등록번호: 742-86-00224 <a href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=7428600224" target="_blank">[사업자정보확인]</a><br/>통신판매업 신고번호: 2017-서울강남-01779<br/>고객센터: 02-565-5988<br/><br/>
# <span class="copyrights">© 2021 MangoPlate Co., Ltd. All rights reserved.</span>
# </p>
# </small>
# </div>
# </div>
# </footer>
# <script charset="utf-8" id="map_info_window_template" type="text/template">
#   <div class="restaurant-in-map">
#     <figure class="restaurant-item">
#         <div class="thumb">
#           <a href="/restaurants/{{ restaurant_key }}">
#             <div class="inner">
#               <img src="{{picture_url}}" alt="{{ name }} 사진" class="center-crop" onerror="this.src='https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg'"  />
#             </div>
#           </a>
#         </div>
#       <figcaption>
#         <div class="info">
#           <span class="title"><a href="/restaurants/{{ restaurant_key }}">{{ name }}</a></span>
#           <strong class="point {{ get_expected_rating_class(official_rating_available) }}">{{ rating }}</strong>
#           <p class="etc">{{ metro }} - {{ subcuisine }}</p>
#
#           <p class="status-cnt">
#             <em class="review"><span class="hidden">리뷰수: </span>{{ review_count }}</em>
#             <em class="favorite"><span class="hidden">가고싶다 수: </span>{{ wannago_count }}</em>
#           </p>
#         </div>
#       </figcaption>
#     </figure>
#   </div>
# </script>
# <script type="text/javascript">
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 						(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 					m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-39170270-2', 'auto');
# 	ga('send', 'pageview');
#
# </script>
# <script src="/assets/dist/vendor.all.min-ca5bcef18b6eb37efe83cc77be5c25e8177c177f327aee8a96399966c51d0d33.js"></script>
# <!-- Facebook SDK -->
# <script id="facebook-jssdk" src="//connect.facebook.net/ko_KR/sdk.js"></script>
# <script type="text/javascript">
#   // \x3C/ is <
#   if (!window.FB) {
#     $("#facebook-jssdk").remove();
#     document.write('<script id="facebook-jssdk" src="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/facebook_sdk_20190510.js">\x3C/script>')
#   }
# </script>
# <!-- Kakao SDK -->
# <script src="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/js/kakao-sdk/1.36.6/kakao.min.js"></script>
# <!-- Apple SDK -->
# <script src="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/js/apple-sdk/1.5.3/appleid.auth.js"></script>
# <script type="text/javascript">
#   if (!window.Kakao) {
#     document.write('<script src="//developers.kakao.com/sdk/js/kakao.min.js">\x3C/script>')
#   }
#   if (!window.AppleID) {
#     document.write('<script src="//appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js">\x3C/script>')
#   }
#   // I18n Default Setting
#   if (window.I18n) {
#     I18n.defaultLocale = "ko";
#     I18n.locale = "ko";
#   }
# </script>
# <script src="https://cdn.branch.io/branch-latest.min.js" type="text/javascript"></script>
# <!-- Branch io SDK -->
# <script charset="utf-8" type="text/javascript">
#   // \x3C/ is <
#   if (!window.branch) {
#     document.write('<script src="/assets/vendor/branch_io.min.js">\x3C/script>')
#   }
# </script>
# <script src="/assets/dist/search.all.min-e59d5d08b251145267a1985ad9c7253fbc39fdee5054d25204e981d38acbee74.js"></script>
# <script src="/packs/search-229ac4adff977967266a.js"></script>
# <!-- Start Alexa Certify Javascript -->
# <script type="text/javascript">
# 	_atrk_opts = { atrk_acct:"hTunm1akKd60uG", domain:"mangoplate.com",dynamic: true};
# 	(function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
# </script>
# <noscript><img alt="alexa analytics" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=hTunm1akKd60uG" style="display:none" width="1"/></noscript>
# <!-- End Alexa Certify Javascript -->
# </body>
# </html>
