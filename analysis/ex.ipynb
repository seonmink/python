# %%
import numpy as np

# %%
data=np.loadtxt('./data/ml-1m/ratings.dat',delimiter='::',dtype=np.int64)

# %%
print(data)
print(data.shape)
# Out:
# [[        1      1193         5 978300760]
#  [        1       661         3 978302109]
#  [        1       914         3 978301968]
#  ...
#  [     6040       562         5 956704746]
#  [     6040      1096         4 956715648]
#  [     6040      1097         4 956715569]]
# (1000209, 4)

# %%
data = np.array(data)
data[:20,]
# Out:
# array([[        1,      1193,         5, 978300760],
#        [        1,       661,         3, 978302109],
#        [        1,       914,         3, 978301968],
#        [        1,      3408,         4, 978300275],
#        [        1,      2355,         5, 978824291],
#        [        1,      1197,         3, 978302268],
#        [        1,      1287,         5, 978302039],
#        [        1,      2804,         5, 978300719],
#        [        1,       594,         4, 978302268],
#        [        1,       919,         4, 978301368],
#        [        1,       595,         5, 978824268],
#        [        1,       938,         4, 978301752],
#        [        1,      2398,         4, 978302281],
#        [        1,      2918,         4, 978302124],
#        [        1,      1035,         5, 978301753],
#        [        1,      2791,         4, 978302188],
#        [        1,      2687,         3, 978824268],
#        [        1,      2018,         4, 978301777],
# ...

# %%
data[21:30,:2]
# Out:
# array([[   1,  720],
#        [   1, 1270],
#        [   1,  527],
#        [   1, 2340],
#        [   1,   48],
#        [   1, 1097],
#        [   1, 1721],
#        [   1, 1545],
#        [   1,  745]], dtype=int64)

# %%
print(data[:,2].mean())
print(np.mean(data[:,2]))
# Out:
# 3.581564453029317
# 3.581564453029317

# %%
user_id = np.unique(data[:,0])
print(user_id)

mean_values =[]
for id in user_id: #6040개의 아이디 가져오기 
    data_for_user=data[data[:,0]== id, : ]# 1번 아이디 데이터 가져오기
    value=data_for_user[:,2].mean()
    mean_values.append([id,value])

print('결과:',mean_values[:10])
# Out:
# [   1    2    3 ... 6038 6039 6040]
# 결과: [[1, 4.188679245283019], [2, 3.7131782945736433], [3, 3.9019607843137254], [4, 4.190476190476191], [5, 3.1464646464646466], [6, 3.9014084507042255], [7, 4.32258064516129], [8, 3.884892086330935], [9, 3.7358490566037736], [10, 4.114713216957606]]

# %%
arr_mean_values = np.array(mean_values)
print(arr_mean_values)
# Out:
# [[1.00000000e+00 4.18867925e+00]
#  [2.00000000e+00 3.71317829e+00]
#  [3.00000000e+00 3.90196078e+00]
#  ...
#  [6.03800000e+03 3.80000000e+00]
#  [6.03900000e+03 3.87804878e+00]
#  [6.04000000e+03 3.57771261e+00]]

# %%
print(np.argsort(arr_mean_values[:,1]))
# Out:
# [3597 4485 2743 ... 3323 2338  282]

# %%
print(arr_mean_values[282])
# Out:
# [283.           4.96296296]

# %%
print(np.argsort(arr_mean_values[:,1])[::-1])
# Out:
# [ 282 2338 3323 ... 2743 4485 3597]

# %%
print(arr_mean_values[np.argsort(arr_mean_values[:,1])[-1]])
# Out:
# [283.           4.96296296]

# %%
print(np.max(arr_mean_values[:,1]))
# Out:
# 4.962962962962963

# %%
print(arr_mean_values[np.argmax(arr_mean_values[:,1])])
# Out:
# [283.           4.96296296]

# %%
import numpy as np
data=np.loadtxt('./data/ml-1m/ratings.dat',delimiter='::',dtype=np.int64)
user_id = np.unique(data[:,0])

mean_values =[]
for id in user_id:
      data_for_user=data[data[:,0]== id, : ]
      value=data_for_user[:,2].mean()
      mean_values.append([id,value])
        
print(arr_mean_values[np.argmax(arr_mean_values[:,1])])
# Out:
# [283.           4.96296296]

# %%
import pandas as pd
import numpy as np
#실제 그래프를 그릴 수 있는 서브 함수
import matplotlib.pyplot as plt
import seaborn as sns

#경고표시 생략(일시적으로 생략하는게 좋음) 
import warnings
warnings.filterwarnings(action='ignore')

#한글폰트 지정 
import matplotlib.font_manager as fm
font_name= fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font",family=font_name)

import matplotlib as mpl
mpl.rcParams['axes.unicode_minus']=False

# %%
import folium

# %%
map=folium.Map(location=[36.75859090611619, 126.29061444199664],zoom_start=30)
marker=folium.Marker(location=[36.75859090611619, 126.29061444199664],icon=folium.Icon(color='red',icon='star'))
marker.add_to(map)
map
marker=folium.Marker(location=[36.75859090611619, 126.29061444199664],icon=folium.Icon(color='red',icon='star'),
                    popup='우리집 근처').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
folium.CircleMarker(location=[36.75859090611619, 126.29061444199664],
                   radius=50,color='#ffffgg',fill_color='#fffggg').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
state_unemp=pd.read_csv('data/map/folium_US_Unemployment_Oct2012.csv')

# %%
map=folium.Map(location=[40,-98],zoom_start=4)
map
state_geo='data/map/folium_us-states.json'
map.choropleth(geo_data=state_geo,data=state_unemp,key_on='feature.id',
              columns=['State','Unemployment'],fill_color='YlGn')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
text= open('data/wordcloud/constitution.txt')
text=text.read()
text

wc = WordCloud(max_font_size=50,background_color='pink').generate(text)
plt.figure(figsize=(10,12))
plt.imshow(wc)
# plt.axis('off')

# %%
wc.words_
# Out:
# {'State': 1.0,
#  'United States': 0.8181818181818182,
#  'Law': 0.5151515151515151,
#  'may': 0.5,
#  'Congress': 0.4393939393939394,
#  'House': 0.42424242424242425,
#  'President': 0.3939393939393939,
#  'Section': 0.3333333333333333,
#  'Person': 0.3333333333333333,
#  'Office': 0.3333333333333333,
#  'Year': 0.3181818181818182,
#  'time': 0.30303030303030304,
#  'Representative': 0.2878787878787879,
#  'one': 0.2878787878787879,
#  'Case': 0.2878787878787879,
#  'Senate': 0.25757575757575757,
#  'Power': 0.24242424242424243,
#  'Constitution': 0.21212121212121213,
#  'Vote': 0.21212121212121213,
#  'Legislature': 0.19696969696969696,
#  'thereof': 0.18181818181818182,
#  'Senator': 0.18181818181818182,
#  'Officer': 0.18181818181818182,
#  'every': 0.16666666666666666,
#  'Citizen': 0.16666666666666666,
#  'Member': 0.16666666666666666,
#  'make': 0.15151515151515152,
#  'Consent': 0.15151515151515152,
#  'Bill': 0.15151515151515152,
#  'Article': 0.13636363636363635,
# ...

# %%
from PIL import Image
# Image.open('data/wordcloud/alice_mask.png')
am=np.array(Image.open('data/wordcloud/alice_mask.png'))
plt.figure(figsize=(10,10))
plt.imshow(am)
# Out:
# (-0.5, 639.5, 479.5, -0.5)

# %%
wc= WordCloud(max_font_size=40,background_color='black',mask=am).generate(text)
plt.figure(figsize=(12,12))
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 639.5, 479.5, -0.5)

# %%
text=open('data/wordcloud/alice.txt').read()
text

stopwords=set(STOPWORDS)
stopwords.add('said')

wc= WordCloud(max_font_size=40,background_color='black',mask=am,
             stopwords=stopwords,max_words=200).generate(text)
plt.figure(figsize=(12,12))
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 639.5, 479.5, -0.5)

# %%
alice_color=np.array(Image.open('data/wordcloud/alice.png'))

plt.figure(figsize=(8,8))
plt.imshow(alice_color)

# %%
import wordcloud
wc= WordCloud(max_font_size=40,background_color='black',mask=alice_color,
             stopwords=stopwords,max_words=200).generate(text)

image_color = wordcloud.imageColorGenerator(alice_color)

plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-e449ef657446> in <module>
#       3              stopwords=stopwords,max_words=200).generate(text)
#       4
# ----> 5 image_color = wordcloud.imageColorGenerator(alice_color)
#       6
#       7 plt.figure(figsize=(12,12))
#
# AttributeError: module 'wordcloud' has no attribute 'imageColorGenerator'

# %%
from konlpy.tag import Okt

# %%
import tweepy
tweepy.__version__
# Out:
# '3.10.0'

# %%
okt=Okt()
okt.nouns('쥬는 선민이를 좋아해')
# Out:
# ['쥬', '선민']

# %%
import pandas as pd
import numpy as np
#실제 그래프를 그릴 수 있는 서브 함수
import matplotlib.pyplot as plt
import seaborn as sns

#경고표시 생략(일시적으로 생략하는게 좋음) 
import warnings
warnings.filterwarnings(action='ignore')

#한글폰트 지정 
import matplotlib.font_manager as fm
font_name= fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font",family=font_name)

import matplotlib as mpl
mpl.rcParams['axes.unicode_minus']=False

import urllib.request as req
from urllib.request import urlopen
from urllib.error import HTTPError, URLError
import urllib.parse
from bs4 import BeautifulSoup
import requests

# %%
df=pd.read_csv('data/sandwiches_map.csv',index_col=0)

# %%
df.head()
# Out:
#                    Menu                    Cafe  \
# Rank
# 1                   BLT             Old Oak Tap
# 2         Fried Bologna               Au Cheval
# 3     Woodland Mushroom                    Xoco
# 4            Roast Beef               Al’s Deli
# 5                  PB&L  Publican Quality Meats
#
#                                                ReadMore  Price  \
# Rank
# 1     https://www.chicagomag.com/Chicago-Magazine/No...    $10
# 2     https://www.chicagomag.com/Chicago-Magazine/No...     $9
# 3     https://www.chicagomag.com/Chicago-Magazine/No...  $9.50
# 4     https://www.chicagomag.com/Chicago-Magazine/No...  $9.40
# 5     https://www.chicagomag.com/Chicago-Magazine/No...    $10
#
#                    Address   Latitude  Longitude
# Rank
# 1     2109 W. Chicago Ave.  41.895605 -87.679961
# 2      800 W. Randolph St.  41.884658 -87.647667
# 3         445 N. Clark St.  41.890523 -87.630783
# 4            914 Noyes St.  42.058322 -87.683748
# ...

# %%
import folium

map= folium.Map(location=[df['Latitude'].mean(),df['Longitude'].mean()],
               zoom_start=11)
map
folium.Marker([df['Latitude'].mean(),df['Longitude'].mean()],popup='center').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
url='https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20170806'
page=urlopen(url)
soup=BeautifulSoup(page,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&amp;date=20170806" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div','tit5')
print(soup.find_all('div','tit5')[0])
# Out:
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=62586" title="다크 나이트">다크 나이트</a>
# </div>

# %%
print(soup.find_all('div','tit5')[0].get_text())
# Out:
# 다크 나이트

# %%
soup.find_all('td','point')[0]
print(soup.find_all('td','point')[0].get_text())
# Out:
# 9.32

# %%
movie_name = [soup.find_all('div','tit5')[n].get_text() for n in range(47)]
movie_point = [soup.find_all('td','point')[n].get_text() for n in range(47)]

# %%
print(movie_name,movie_point)
# Out:
# ['\n다크 나이트\n', '\n킹 오브 프리즘 프라이드 더 히어로\n', '\n킹 오브 프리즘\n', '\n내 사랑\n', '\n오즈의 마법사\n', '\n서서평, 천천히 평온하게\n', '\n로보캅\n', '\n플립\n', '\n헤드윅\n', '\n댄서\n', '\n이터널 선샤인\n', '\n명탐정 코난:진홍의 연가\n', '\n샤인\n', '\n택시운전사\n', '\n올드보이\n', '\n어네스트와 셀레스틴\n', '\n기쿠지로의 여름\n', '\n파도가 지나간 자리\n', '\n노무현입니다\n', '\n파이트 클럽\n', '\n스타쉽 트루퍼스\n', '\n청원\n', '\n토탈 리콜\n', '\n극장판 짱구는 못말려 : 습격!! 외계인 덩덩이\n', '\n너의 이름은.\n', '\n연애담\n', '\n슈퍼배드 3\n', '\n꿈의 제인\n', '\n심야식당2\n', '\n라라랜드\n', '\n카3: 새로운 도전\n', '\n오두막\n', '\n스파이더맨: 홈커밍\n', '\n옥자\n', '\n500일의 썸머\n', '\n복수는 나의 것\n', '\n덩케르크\n', '\n예수는 역사다\n', '\n매치 포인트\n', '\n7번째 내가 죽던 날\n', '\n47 미터\n', '\n친절한 금자씨\n', '\n송 투 송\n', '\n그 후\n', '\n박쥐\n', '\n싸이보그지만 괜찮아\n', '\n군함도\n'] ['9.32', '9.27', '9.25', '9.24', '9.23', '9.23', '9.21', '9.20', '9.18', '9.14', '9.10', '9.10', '9.09', '9.08', '9.05', '9.05', '9.02', '9.00', '8.93', '8.91', '8.90', '8.87', '8.86', '8.83', '8.76', '8.75', '8.73', '8.70', '8.62', '8.59', '8.58', '8.48', '8.48', '8.47', '8.39', '8.34', '8.32', '8.12', '7.
# ...

# %%
datearr = pd.date_range('2017-05',periods=100)
datearr
# Out:
# DatetimeIndex(['2017-05-01', '2017-05-02', '2017-05-03', '2017-05-04',
#                '2017-05-05', '2017-05-06', '2017-05-07', '2017-05-08',
#                '2017-05-09', '2017-05-10', '2017-05-11', '2017-05-12',
#                '2017-05-13', '2017-05-14', '2017-05-15', '2017-05-16',
#                '2017-05-17', '2017-05-18', '2017-05-19', '2017-05-20',
#                '2017-05-21', '2017-05-22', '2017-05-23', '2017-05-24',
#                '2017-05-25', '2017-05-26', '2017-05-27', '2017-05-28',
#                '2017-05-29', '2017-05-30', '2017-05-31', '2017-06-01',
#                '2017-06-02', '2017-06-03', '2017-06-04', '2017-06-05',
#                '2017-06-06', '2017-06-07', '2017-06-08', '2017-06-09',
#                '2017-06-10', '2017-06-11', '2017-06-12', '2017-06-13',
#                '2017-06-14', '2017-06-15', '2017-06-16', '2017-06-17',
#                '2017-06-18', '2017-06-19', '2017-06-20', '2017-06-21',
# ...

# %%
from tqdm import tqdm_notebook

movie_date=[]
movie_name=[]
movie_point=[]

for today in tqdm_notebook(datearr):
    url ='https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date={}'
    page = urlopen(url.format(today.strftime('Y%m%d')))
    soup = BeautifulSoup(page,'html.parser')
    
    cnt = len(soup.find_all('td','point'))
    
    movie_date.extend([today for n in range(cnt)])
    movie_name.extend(soup.find_all('div','tit5')[n].get_text().strip('\n') for n in range(cnt))
    movie_point.extend([soup.find_all('td','point')[n].get_text().strip('\n') for n in range(cnt)])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from tqdm import tqdm_notebook

movie_date=[]
movie_name=[]
movie_point=[]

for today in tqdm_notebook(datearr):
    url= 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date={}'
    #인덱스는 2017-08-08 형태 --> 네이버는 20170808 가공처리 해야함
    page =urlopen(url.format(today.strftime('%Y%m%d')))
    soup = BeautifulSoup(page,'html.parser')
    
    # 날마다 영화개수가 다를 수 있음 그래서 세줘야 함
    cnt = len(soup.find_all('td','point'))
    
    movie_date.extend([today for n in range(cnt)])
    movie_name.extend(soup.find_all('div','tit5')[n].get_text().strip('\n') for n in range(cnt))
    movie_point.extend([soup.find_all('td','point')[n].get_text().strip('\n') for n in range(cnt)])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
len( movie_date), len(movie_point),len(movie_name)
# Out:
# (4723, 4723, 4723)

# %%
df= pd.DataFrame({'date':movie_date,'name':movie_name,'point':movie_point})
df.head()
# Out:
#         date        name point
# 0 2017-05-01      히든 피겨스  9.38
# 1 2017-05-01   사운드 오브 뮤직  9.36
# 2 2017-05-01      시네마 천국  9.29
# 3 2017-05-01      미스 슬로운  9.26
# 4 2017-05-01  잉여들의 히치하이킹  9.25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4723 entries, 0 to 4722
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4723 non-null   datetime64[ns]
#  1   name    4723 non-null   object
#  2   point   4723 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 110.8+ KB

# %%
df['point']=df['point'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4723 entries, 0 to 4722
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4723 non-null   datetime64[ns]
#  1   name    4723 non-null   object
#  2   point   4723 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 110.8+ KB

# %%
from selenium import webdriver

# %%
driver=webdriver.Chrome('C:/Program Files/cd/chromedriver.exe')
driver.get('https://www.naver.com')

# %%
driver.close()

# %%
d = webdriver.Chrome('C:/Program Files/cd/chromedriver.exe')
d.get('https://logins.daum.net/accounts/signinform.do?url=https%3A%2F%2Fwww.daum.net%2F')

# %%
login=d.find_element_by_id('id')
login.clear()
login.send_keys('blue4sky4')
pwd=d.find_element_by_id('inputPwd')
pwd.send_keys('4897dmsthf!!')

xpath="""//*[@id="loginBtn"]"""
d.find_element_by_xpath(xpath).click()

# %%
d.close()

# %%
from selenium import webdriver
driver=webdriver.Chrome('C:/Program Files/cd/chromedriver.exe')
driver.get('https://www.opinet.co.kr/searRgSelect.do')

# %%
si_list_raw=driver.find_element_by_xpath("""//*[@id="SIDO_NM0"]""")
si_list=si_list_raw.find_elements_by_tag_name('option')
print(si_list[1].get_attribute('value'))

si_name = [option.get_attribute('value') for option in si_list]
si_name.remove('')
si_name
# Out:
# 서울특별시
# ['서울특별시',
#  '부산광역시',
#  '대구광역시',
#  '인천광역시',
#  '광주광역시',
#  '대전광역시',
#  '울산광역시',
#  '세종특별자치시',
#  '경기도',
#  '강원도',
#  '충청북도',
#  '충청남도',
#  '전라북도',
#  '전라남도',
#  '경상북도',
#  '경상남도',
#  '제주특별자치도']

# %%
element=driver.find_element_by_id('SIDO_NM0')
element.send_keys(si_name[0])

# %%
gu_list_raw=driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list=gu_list_raw.find_elements_by_tag_name('option')
gu_list
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="554cd695-ce08-4904-9aed-ad88616fb126")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="d5eeadb1-6af3-40d0-b862-5feaf7196b8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="e32e819b-50db-4825-9ac2-81d689814214")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="6dc7825c-a6ca-4f20-b554-988222f36af7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="167cc1da-60de-4b9e-816f-c39ed5692cb8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="058a1f0f-0123-4d36-a285-4406c00074e8")>,
# ...

# %%
gu_list_raw=driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list=gu_list_raw.find_elements_by_tag_name('option')
gu_list
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="554cd695-ce08-4904-9aed-ad88616fb126")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="d5eeadb1-6af3-40d0-b862-5feaf7196b8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="e32e819b-50db-4825-9ac2-81d689814214")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="6dc7825c-a6ca-4f20-b554-988222f36af7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="167cc1da-60de-4b9e-816f-c39ed5692cb8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1d73f0c8cac9097946f1b961f96c516c", element="058a1f0f-0123-4d36-a285-4406c00074e8")>,
# ...

# %%
print(gu_list[1].get_attribute('value'))
# Out:
# 강남구

# %%
gu_name=[option.get_attribute('value') for option in gu_list]
gu_name.remove('')
gu_name
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
element=driver.find_element_by_id('SIGUNGU_NM0')
element.send_keys(gu_name[11])
